# %%
import tensorflow as tf
from keras import models, layers
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
batch_size = 32
input_shape = (32, 400, 300, 3)
n_classes = 4
epoch = 100
dataset = tf.keras.preprocessing.image_dataset_from_directory("CoLeaf_DataSet",
                                                              shuffle=True,
                                                              image_size=(400, 300),
                                                              batch_size=batch_size)
# Out:
# Found 412 files belonging to 4 classes.

# %%
class_names = dataset.class_names
print(class_names)
print(len(dataset))
# Out:
# ['healthy', 'nitrogen-N', 'phosphorus-P', 'potasium-K']
# 13

# %%
def get_dataset_partition_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=100):
    ds_size = len(ds)
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    test_size = int(test_split * ds_size)
    trn_ds = ds.take(train_size)
    vl_ds = ds.skip(train_size).take(val_size)
    tst_ds = ds.skip(train_size).skip(val_size)
    return trn_ds, vl_ds, tst_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partition_tf(dataset)
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.Resizing(400, 300),
    tf.keras.layers.experimental.preprocessing.Rescaling(1.0 / 255)])
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(2),
])

# %%
model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
     layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(400, 300)),
    layers.MaxPool2D(2, 2),
    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.MaxPool2D(2, 2),
    layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    layers.MaxPool2D(2, 2),
    layers.Conv2D(256, (3, 3), padding='same', activation='relu'),
    layers.MaxPool2D(2, 2),
    layers.Conv2D(256, (3, 3), padding='same', activation='relu'),
    layers.MaxPool2D(2, 2),
    layers.Conv2D(512, (3, 3), padding='same', activation='relu'),
    layers.MaxPool2D(2, 2),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),

])

model.build(input_shape=input_shape)
print(model.summary())
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 400, 300, 3)         0
#
#  sequential_1 (Sequential)   (None, 400, 300, 3)       0
#
#  conv2d (Conv2D)             (None, 400, 300, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 200, 150, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 200, 150, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 100, 75, 64)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 100, 75, 128)      73856
#
#  max_pooling2d_2 (MaxPooling  (None, 50, 37, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 50, 37, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 25, 18, 256)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 25, 18, 256)       590080
#
#  max_pooling2d_4 (MaxPooling  (None, 12, 9, 256)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 12, 9, 512)        1180160
#
#  max_pooling2d_5 (MaxPooling  (None, 6, 4, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 12288)             0
#
#  dense (Dense)               (None, 512)               6291968
#
#  dense_1 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 8,452,676
# Trainable params: 8,452,676
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)
history = model.fit(
    train_ds,
    epochs=epoch,
    batch_size=batch_size,
    verbose=1,
    validation_data=val_ds

)

scores = model.evaluate(test_ds)
model.build(input_shape=input_shape)
print(model.summary())
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 10/10 [==============================] - 37s 2s/step - loss: 1.3769 - accuracy: 0.5285 - val_loss: 1.1489 - val_accuracy: 0.5625
# Epoch 2/100
# 10/10 [==============================] - 6s 597ms/step - loss: 1.0888 - accuracy: 0.5823 - val_loss: 1.0922 - val_accuracy: 0.5625
# Epoch 3/100
# 10/10 [==============================] - 6s 591ms/step - loss: 1.0178 - accuracy: 0.6139 - val_loss: 1.0405 - val_accuracy: 0.5625
# Epoch 4/100
# 10/10 [==============================] - 6s 590ms/step - loss: 0.9451 - accuracy: 0.6139 - val_loss: 1.0072 - val_accuracy: 0.5625
# Epoch 5/100
# 10/10 [==============================] - 6s 585ms/step - loss: 0.9034 - accuracy: 0.6139 - val_loss: 0.8914 - val_accuracy: 0.5625
# Epoch 6/100
# 10/10 [==============================] - 6s 588ms/step - loss: 0.8198 - accuracy: 0.6139 - val_loss: 0.7926 - val_accuracy: 0.5625
# Epoch 7/100
# Epoch 44/100
# 10/10 [==============================] - 6s 581ms/step - loss: 0.3429 - accuracy: 0.8576 - val_loss: 0.4871 - val_accuracy: 0.8438
# Epoch 45/100
# 10/10 [==============================] - 6s 578ms/step - loss: 0.3837 - accuracy: 0.8449 - val_loss: 0.2865 - val_accuracy: 0.9062
# Epoch 46/100
# 10/10 [==============================] - 6s 575ms/step - loss: 0.5946 - accuracy: 0.7595 - val_loss: 0.5132 - val_accuracy: 0.8750
# Epoch 47/100
# 10/10 [==============================] - 6s 585ms/step - loss: 0.5631 - accuracy: 0.7595 - val_loss: 0.4385 - val_accuracy: 0.8438
# Epoch 48/100
# 10/10 [==============================] - 6s 582ms/step - loss: 0.5458 - accuracy: 0.7658 - val_loss: 0.4837 - val_accuracy: 0.8125
# Epoch 49/100
# 10/10 [==============================] - 6s 584ms/step - loss: 0.4898 - accuracy: 0.8070 - val_loss: 0.4962 - val_accuracy: 0.8438
# Epoch 50/100
# 10/10 [==============================] - 6s 582ms/step - loss: 0.4219 - accuracy: 0.8418 - val_loss: 0.3913 - val_accuracy: 0.8750
# Epoch 51/100
# 10/10 [==============================] - 6s 584ms/step - loss: 0.3512 - accuracy: 0.8829 - val_loss: 0.4356 - val_accuracy: 0.9062
# Epoch 52/100
# 10/10 [==============================] - 6s 581ms/step - loss: 0.3956 - accuracy: 0.8576 - val_loss: 0.3284 - val_accuracy: 0.8438
# Epoch 53/100
# 10/10 [==============================] - 6s 587ms/step - loss: 0.3669 - accuracy: 0.8608 - val_loss: 0.2655 - val_accuracy: 0.9375
# Epoch 54/100
# 10/10 [==============================] - 6s 578ms/step - loss: 0.3298 - accuracy: 0.8513 - val_loss: 0.3686 - val_accuracy: 0.9062
# Epoch 55/100
# 10/10 [==============================] - 6s 592ms/step - loss: 0.3876 - accuracy: 0.8354 - val_loss: 0.3621 - val_accuracy: 0.8125
# Epoch 56/100
# 10/10 [==============================] - 6s 576ms/step - loss: 0.3587 - accuracy: 0.8608 - val_loss: 0.2534 - val_accuracy: 0.9062
# Epoch 57/100
# 10/10 [==============================] - 6s 589ms/step - loss: 0.4017 - accuracy: 0.8291 - val_loss: 0.3722 - val_accuracy: 0.8750
# Epoch 58/100
# 10/10 [==============================] - 6s 584ms/step - loss: 0.3406 - accuracy: 0.8703 - val_loss: 0.4497 - val_accuracy: 0.8438
# Epoch 59/100
# 10/10 [==============================] - 6s 577ms/step - loss: 0.2963 - accuracy: 0.8766 - val_loss: 0.2650 - val_accuracy: 0.9062
# Epoch 60/100
# 10/10 [==============================] - 6s 593ms/step - loss: 0.3031 - accuracy: 0.8797 - val_loss: 0.2769 - val_accuracy: 0.9062
# Epoch 61/100
# 10/10 [==============================] - 6s 582ms/step - loss: 0.3243 - accuracy: 0.8576 - val_loss: 0.2327 - val_accuracy: 0.9375
# Epoch 62/100
# 10/10 [==============================] - 6s 581ms/step - loss: 0.3271 - accuracy: 0.8639 - val_loss: 0.3231 - val_accuracy: 0.9062
# Epoch 63/100
# 10/10 [==============================] - 6s 576ms/step - loss: 0.3016 - accuracy: 0.8766 - val_loss: 0.4148 - val_accuracy: 0.8750
# Epoch 64/100
# 10/10 [==============================] - 6s 580ms/step - loss: 0.2853 - accuracy: 0.8703 - val_loss: 0.2484 - val_accuracy: 0.9062
# Epoch 65/100
# 10/10 [==============================] - 6s 584ms/step - loss: 0.2544 - accuracy: 0.8956 - val_loss: 0.4768 - val_accuracy: 0.8750
# Epoch 66/100
# 10/10 [==============================] - 6s 586ms/step - loss: 0.2597 - accuracy: 0.8766 - val_loss: 0.3468 - val_accuracy: 0.8438
# Epoch 67/100
# 10/10 [==============================] - 6s 583ms/step - loss: 0.2568 - accuracy: 0.9019 - val_loss: 0.2241 - val_accuracy: 0.9062
# Epoch 68/100
# 10/10 [==============================] - 6s 579ms/step - loss: 0.2509 - accuracy: 0.8987 - val_loss: 0.3156 - val_accuracy: 0.8750
# Epoch 69/100
# 10/10 [==============================] - 6s 579ms/step - loss: 0.2493 - accuracy: 0.8956 - val_loss: 0.2116 - val_accuracy: 0.9375
# Epoch 70/100
# 10/10 [==============================] - 6s 583ms/step - loss: 0.3224 - accuracy: 0.8639 - val_loss: 0.1964 - val_accuracy: 0.9375
# Epoch 71/100
# 10/10 [==============================] - 6s 586ms/step - loss: 0.2802 - accuracy: 0.8829 - val_loss: 0.3635 - val_accuracy: 0.8750
# Epoch 72/100
# 10/10 [==============================] - 6s 582ms/step - loss: 0.2537 - accuracy: 0.9019 - val_loss: 0.3787 - val_accuracy: 0.9062
# Epoch 73/100
# 10/10 [==============================] - 6s 573ms/step - loss: 0.2128 - accuracy: 0.9051 - val_loss: 0.3402 - val_accuracy: 0.8750
# Epoch 74/100
#  5/10 [==============>...............] - ETA: 2s - loss: 0.3306 - accuracy: 0.8750

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
plt.figure(figsize =(8,8))
plt.subplot(1,2,1)
plt.plot(range(epoch),acc,label='Training Accuracy')
plt.plot(range(epoch),val_acc,label='Val Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1,2,2)
plt.plot(range(epoch),loss,label='Training Loss')
plt.plot(range(epoch),val_loss,label='Val Loss')
plt.legend(loc='lower right')
plt.title('Training and Validation Loss')
import os
fig_version = max([int(i) for i in os.listdir("./figures")+ [0]])+1
plt.savefig(f"./models/{fig_version}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 acc = history.history['accuracy']
#       2 val_acc = history.history['val_accuracy']
#       3 loss = history.history['loss']
#
# NameError: name 'history' is not defined

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(10,40))
for images,labels in test_ds.take(1):
    for i in range(30):
        ax = plt.subplot(10,3,i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
    
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]
        plt.title(f"Actual:{actual_class},\n predicted: {predicted_class},\n Confidence: {confidence}%")
        plt.axis('off')
# Out:
# 1/1 [==============================] - 1s 624ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
model_version = max([int(i) for i in os.listdir("./models")+ [0]])+1
model.save(f"./models/{model_version}")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./models/1\assets
# INFO:tensorflow:Assets written to: ./models/1\assets
